# %%
import pandas as pd
df = pd.read_csv('ramen-ratings.csv')
df.head()
# Out:
#    Review #           Brand  \
# 0      2580       New Touch
# 1      2579        Just Way
# 2      2578          Nissin
# 3      2577         Wei Lih
# 4      2576  Ching's Secret
#
#                                              Variety Style Country Stars  \
# 0                          T's Restaurant Tantanmen    Cup   Japan  3.75
# 1  Noodles Spicy Hot Sesame Spicy Hot Sesame Guan...  Pack  Taiwan     1
# 2                      Cup Noodles Chicken Vegetable   Cup     USA  2.25
# 3                      GGE Ramen Snack Tomato Flavor  Pack  Taiwan  2.75
# 4                                    Singapore Curry  Pack   India  3.75
#
#   Top Ten
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2580 entries, 0 to 2579
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Review #  2580 non-null   int64
#  1   Brand     2580 non-null   object
#  2   Variety   2580 non-null   object
#  3   Style     2578 non-null   object
#  4   Country   2580 non-null   object
#  5   Stars     2580 non-null   object
#  6   Top Ten   41 non-null     object
# dtypes: int64(1), object(6)
# memory usage: 141.2+ KB

# %%
dfs = [df] 
for df in dfs:
    print(df.isna().sum())
# Out:
# Review #       0
# Brand          0
# Variety        0
# Style          2
# Country        0
# Stars          0
# Top Ten     2539
# dtype: int64

# %%
df['Top Ten'].value_counts()
# Out:
# \n          4
# 2016 #10    1
# 2012 #10    1
# 2014 #1     1
# 2013 #1     1
# 2013 #2     1
# 2013 #4     1
# 2013 #9     1
# 2013 #3     1
# 2012 #7     1
# 2016 #1     1
# 2012 #5     1
# 2012 #3     1
# 2012 #6     1
# 2012 #9     1
# 2012 #1     1
# 2012 #2     1
# 2013 #6     1
# 2014 #6     1
# 2014 #5     1
# 2014 #8     1
# 2014 #10    1
# 2016 #8     1
# 2016 #5     1
# 2016 #9     1
# 2016 #7     1
# 2015 #10    1
# 2015 #7     1
# 2015 #4     1
# 2015 #9     1
# 2015 #6     1
# 2015 #1     1
# 2013 #10    1
# 2015 #8     1
# 2014 #7     1
# 2014 #4     1
# 2014 #9     1
# 2012 #4     1
# Name: Top Ten, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2580 entries, 0 to 2579
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Review #  2580 non-null   int64
#  1   Brand     2580 non-null   object
#  2   Variety   2580 non-null   object
#  3   Style     2578 non-null   object
#  4   Country   2580 non-null   object
#  5   Stars     2580 non-null   object
#  6   Top Ten   41 non-null     object
# dtypes: int64(1), object(6)
# memory usage: 141.2+ KB

# %% [markdown]
# print('Row count is:', len(df.index))

# %%
df[['Year', 'Raiting']] = df['Top Ten'].apply(lambda x: pd.Series(str(x).split(" ")))
#data[['Year', 'Raiting']] = df['Top Ten'].str.split(" ", expand = True)
#data.drop(['Top Ten'], axis=1)
df.drop(['Top Ten'],axis=1,inplace=True)
df.head()
# Out:
#    Review #           Brand  \
# 0      2580       New Touch
# 1      2579        Just Way
# 2      2578          Nissin
# 3      2577         Wei Lih
# 4      2576  Ching's Secret
#
#                                              Variety Style Country Stars Year  \
# 0                          T's Restaurant Tantanmen    Cup   Japan  3.75  nan
# 1  Noodles Spicy Hot Sesame Spicy Hot Sesame Guan...  Pack  Taiwan     1  nan
# 2                      Cup Noodles Chicken Vegetable   Cup     USA  2.25  nan
# 3                      GGE Ramen Snack Tomato Flavor  Pack  Taiwan  2.75  nan
# 4                                    Singapore Curry  Pack   India  3.75  nan
#
#   Raiting
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN

# %%
df.Year.value_counts()
# Out:
# nan     2539
# 2012       9
# 2014       8
# 2015       7
# 2013       7
# 2016       6
# \n         4
# Name: Year, dtype: int64

# %%
alt.__version__
# Out:
# '4.2.2'

# %%
df.Raiting.value_counts()
# Out:
# #10    5
# #1     5
# #9     5
# #7     4
# #4     4
# #6     4
# #8     3
# #5     3
# #2     2
# #3     2
# Name: Raiting, dtype: int64

# %%
dfs2 = [df] 
for df in dfs2:
    print(df.isna().sum())
# Out:
# Review #       0
# Brand          0
# Variety        0
# Style          2
# Country        0
# Stars          0
# Year           0
# Raiting     2543
# dtype: int64

# %%
df['Country'] = df['Country'].replace('United States','USA')

# %% [markdown]
# indexAge = df[ (df['Country'] == 'Japan')].index
# df.drop(indexAge , inplace=True)
# df.head(15)

# %%
options = ['South Korea']
  
# selecting rows based on condition

rdf = df[df['Country'].isin(options)]
rdf.head(50)
# Out:
#      Review #          Brand                                          Variety  \
# 5        2575  Samyang Foods                           Kimchi song Song Ramen
# 12       2568       Nongshim               Mr. Bibim Stir-Fried Kimchi Flavor
# 19       2561          Paldo                                  Premium Gomtang
# 25       2555  Samyang Foods                        Song Song Kimchi Big Bowl
# 30       2550  Samyang Foods                                 Paegaejang Ramen
# 32       2548         Ottogi            Plain Instant Noodle No Soup Included
# 47       2533       Nongshim                                Shin Ramyun Black
# 50       2530         Ottogi         Ppushu Ppushu Noodle Snack Honey Butter
# 54       2526  Samyang Foods                               Jjamppong Big Bowl
# 57       2523       Nongshim                         Budae Jjigae Noodle Soup
# 61       2519    Guava Story                Anchovy Flavor Guava Rice Noodles
# ...

# %%
df3 = rdf.reset_index()
pd.melt(rdf, id_vars='Brand', value_vars=['Variety', 'Style' ])
# Out:
#              Brand variable                               value
# 0    Samyang Foods  Variety              Kimchi song Song Ramen
# 1         Nongshim  Variety  Mr. Bibim Stir-Fried Kimchi Flavor
# 2            Paldo  Variety                     Premium Gomtang
# 3    Samyang Foods  Variety           Song Song Kimchi Big Bowl
# 4    Samyang Foods  Variety                    Paegaejang Ramen
# ..             ...      ...                                 ...
# 613        Samyang    Style                                Pack
# 614        Samyang    Style                                Pack
# 615        Samyang    Style                                Pack
# 616    Six Fortune    Style                                Pack
# 617          Sutah    Style                                 Cup
#
# [618 rows x 3 columns]

# %%
brush = alt.selection(type='interval')

points = alt.Chart(rdf).mark_point().encode(
    x='Brand',
    y='Variety',
    color=alt.condition(brush, 'Style', alt.value('lightgray'))
).add_selection(
    brush
)

bars = alt.Chart(rdf).mark_bar().encode(
    y='Style',
    color='Style',
    x='count(Style)'
).transform_filter(
    brush
)
points & bars
# Out:
# alt.VConcatChart(...)

# %%
alt.Chart(df).mark_tick().encode(
    x='Country',
    y='Style',
    
)
# Out:
# alt.Chart(...)

# %%
'''alt.Chart(rdf).mark_point().encode(
    y='Brand',
    x='count(Brand)'
)'''

bars = alt.Chart(rdf).mark_bar().encode(
    y=alt.Y('Brand:N', sort='-x'),
    x='count(Brand)'
    
)

text = bars.mark_text(
    align='left',
    baseline='middle',
    dx=3  # Nudges text to right so it doesn't appear on top of the bar
).encode(
    text='count(Brand):Q'
)

(bars + text).properties(height=900)
# Out:
# alt.LayerChart(...)

# %%
df['Brand'].value_counts()
# Out:
# Nissin           381
# Nongshim          98
# Maruchan          76
# Mama              71
# Paldo             66
#                 ...
# Golden Wonder      1
# Peyang             1
# Sanrio             1
# China Best         1
# Westbrae           1
# Name: Brand, Length: 355, dtype: int64

# %%
df.head()
# Out:
#    Review #           Brand  \
# 0      2580       New Touch
# 1      2579        Just Way
# 2      2578          Nissin
# 3      2577         Wei Lih
# 4      2576  Ching's Secret
#
#                                              Variety Style Country Stars Year  \
# 0                          T's Restaurant Tantanmen    Cup   Japan  3.75  nan
# 1  Noodles Spicy Hot Sesame Spicy Hot Sesame Guan...  Pack  Taiwan     1  nan
# 2                      Cup Noodles Chicken Vegetable   Cup     USA  2.25  nan
# 3                      GGE Ramen Snack Tomato Flavor  Pack  Taiwan  2.75  nan
# 4                                    Singapore Curry  Pack   India  3.75  nan
#
#   Raiting
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN

# %%
df.Country.value_counts()
# Out:
# Japan          352
# USA            324
# South Korea    309
# Taiwan         224
# Thailand       191
# China          169
# Malaysia       156
# Hong Kong      137
# Indonesia      126
# Singapore      109
# Vietnam        108
# UK              69
# Philippines     47
# Canada          41
# India           31
# Germany         27
# Mexico          25
# Australia       22
# Netherlands     15
# Nepal           14
# Myanmar         14
# Hungary          9
# Pakistan         9
# Bangladesh       7
# Colombia         6
# Cambodia         5
# Brazil           5
# Poland           4
# Holland          4
# Fiji             4
# Sweden           3
# Sarawak          3
# Finland          3
# Dubai            3
# Ghana            2
# Estonia          2
# Nigeria          1
# Name: Country, dtype: int64

# %% [markdown]
# chart = alt.Chart(df).mark_bar().encode(
#     x='Brand',
#     y='Country',
# )
# print(chart.to_json())

# %%
import matplotlib.pyplot as plt
df2 = df.groupby(['Country','Brand'])['Brand'].size()
print(df2)
df2.plot.bar(color="blue")
plt.show()
# Out:
# Country    Brand
# Australia  Fantastic         6
#            Maggi             1
#            Singa-Me          3
#            Suimin            8
#            Trident           4
#                             ..
# Vietnam    Unif / Tung-I     1
#            United            3
#            Ve Wong           3
#            Vifon            32
#            Vina Acecook     34
# Name: Brand, Length: 422, dtype: int64

# %%
data.head()
# Out:
#    Review #           Brand  \
# 0      2580       New Touch
# 1      2579        Just Way
# 2      2578          Nissin
# 3      2577         Wei Lih
# 4      2576  Ching's Secret
#
#                                              Variety Style Country Stars Year  \
# 0                          T's Restaurant Tantanmen    Cup     NaN  3.75  nan
# 1  Noodles Spicy Hot Sesame Spicy Hot Sesame Guan...  Pack     NaN     1  nan
# 2                      Cup Noodles Chicken Vegetable   Cup     NaN  2.25  nan
# 3                      GGE Ramen Snack Tomato Flavor  Pack     NaN  2.75  nan
# 4                                    Singapore Curry  Pack     NaN  3.75  nan
#
#   Raiting
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN

# %%
alt.Chart(df).mark_bar().encode(
    x='count(Brand):Q',
    y=alt.Y('Country:N',sort='x')
)
# Out:
# alt.Chart(...)

# %%
df_long = df.melt(['Country', 'Brand'])
df_long.head(10)
# Out:
#        Country           Brand  variable value
# 0        Japan       New Touch  Review #  2580
# 1       Taiwan        Just Way  Review #  2579
# 2          USA          Nissin  Review #  2578
# 3       Taiwan         Wei Lih  Review #  2577
# 4        India  Ching's Secret  Review #  2576
# 5  South Korea   Samyang Foods  Review #  2575
# 6        Japan         Acecook  Review #  2574
# 7        Japan     Ikeda Shoku  Review #  2573
# 8        Japan      Ripe'n'Dry  Review #  2572
# 9    Singapore            KOKA  Review #  2571

# %%
alt.Chart(df).mark_bar().encode(
    column='Country',
    x='Style',
    y='count(Brand)',
    color='Brand'
).properties(width=220)
# Out:
# alt.Chart(...)
